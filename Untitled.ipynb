# %%
import pickle
import numpy
import numpy as np  
import scipy.special 
import matplotlib.pyplot as plt

# %%
# %%bash
# ls
# Out:
# alphafold
# apps
# build
# config_runner.py
# docker
# lddt_score.py
# LICENSE
# mct1_results_4.pkl
# notebooks
# output.pkl
# output.txt
# prediction_result_16_32_edited.pkl
# prediction_result_edited_512_1024.pkl
# __pycache__
# README.md
# relaxed_model_1.pdb
# requirements.txt
# result_model_1_multimer.pkl
# result_model_5.pkl
# run_alphafold.py
# scripts
# setup.py
# test_run_alphafold.py
# Untitled.ipynb
# vendor

# %%
with open('prediction_result_edited_512_1024.pkl', 'rb') as f:
    edited = pickle.load(f)
    
with open("mct1_results_4.pkl", 'rb') as f:
    mct1 = pickle.load(f)

# %%
mct1['distogram']['logits']
# Out:
# array([[[ 1.12127747e+02, -2.19827342e+00, -1.60421963e+01, ...,
#          -7.20597382e+01, -7.25584793e+01, -1.10416969e+02],
#         [ 3.79961777e+00,  3.63434076e+00,  3.81769276e+00, ...,
#           1.49055433e+00,  1.69752932e+00,  2.20375323e+00],
#         [-1.40928280e+00, -3.13820004e-01, -5.66188693e-01, ...,
#          -3.26416397e+00, -3.65843129e+00, -5.82561195e-01],
#         ...,
#         [-7.97073555e+00, -8.75074863e+00, -7.43877554e+00, ...,
#          -1.29562330e+00, -1.30261850e+00,  4.06585741e+00],
#         [-7.61657286e+00, -8.39562225e+00, -7.27279806e+00, ...,
#          -1.29705572e+00, -1.25282931e+00,  3.44150090e+00],
#         [-7.05166626e+00, -7.87366867e+00, -6.70252895e+00, ...,
#          -1.33379352e+00, -1.32047963e+00,  3.74029875e+00]],
#
#        [[ 3.79961777e+00,  3.63434076e+00,  3.81769276e+00, ...,
#           1.49055433e+00,  1.69752932e+00,  2.20375323e+00],
#         [ 1.18573746e+02, -1.54539404e+01, -3.01343117e+01, ...,
# ...

# %%
edited['distogram']['logits']
# Out:
# array([[[ 9.80342560e+01, -5.51730156e+00, -1.68513298e+01, ...,
#          -6.69406586e+01, -6.77103271e+01, -9.91065750e+01],
#         [ 3.83505154e+00,  3.23575616e+00,  3.46660161e+00, ...,
#           9.19096112e-01,  1.14237177e+00,  1.89573789e+00],
#         [-1.45551920e-01,  4.75883245e-01,  4.84526634e-01, ...,
#          -3.56039190e+00, -3.88438654e+00, -6.70841992e-01],
#         ...,
#         [-8.04467583e+00, -8.83386040e+00, -7.80865383e+00, ...,
#          -1.25188637e+00, -1.19515073e+00,  4.48409843e+00],
#         [-8.03734970e+00, -8.86139297e+00, -7.98336172e+00, ...,
#          -1.61109209e+00, -1.51627266e+00,  3.56333828e+00],
#         [-7.61396122e+00, -8.41028214e+00, -7.61627340e+00, ...,
#          -1.35161400e+00, -1.28573585e+00,  4.17863035e+00]],
#
#        [[ 3.83505154e+00,  3.23575616e+00,  3.46660161e+00, ...,
#           9.19096112e-01,  1.14237177e+00,  1.89573789e+00],
#         [ 1.09655846e+02, -1.04260139e+01, -2.59477978e+01, ...,
# ...

# %%
temporary = {}
for i,row in enumerate(mct1['distogram']['logits']):
    for i2, column in row:
#         for i
        temporary[i][i2]

# %%
import pickle
import numpy
import numpy as np

# %%
with open('result_model_5.pkl', 'rb') as f:
    test = pickle.load(f)

# %%
test.keys()
# Out:
# dict_keys(['distogram', 'experimentally_resolved', 'masked_msa', 'predicted_lddt', 'representations', 'structure_module', 'plddt'])

# %%
len(test['distogram']['logits'][0])
# Out:
# 411

# %%
len(test['predicted_lddt']['logits'])
# Out:
# 411

# %%
test['distogram']d
# Out:
# {'bin_edges': array([ 2.3125   ,  2.625    ,  2.9375   ,  3.25     ,  3.5625   ,
#          3.875    ,  4.1875   ,  4.5      ,  4.8125   ,  5.125    ,
#          5.4375   ,  5.75     ,  6.0625   ,  6.375    ,  6.6875   ,
#          6.9999995,  7.3125   ,  7.625    ,  7.9375   ,  8.25     ,
#          8.5625   ,  8.875    ,  9.1875   ,  9.5      ,  9.812499 ,
#         10.124999 , 10.4375   , 10.75     , 11.0625   , 11.375    ,
#         11.687499 , 12.       , 12.3125   , 12.625    , 12.9375   ,
#         13.25     , 13.5625   , 13.874999 , 14.187501 , 14.499999 ,
#         14.812499 , 15.124999 , 15.437499 , 15.75     , 16.0625   ,
#         16.375    , 16.687502 , 16.999998 , 17.312498 , 17.624998 ,
#         17.937498 , 18.25     , 18.5625   , 18.875    , 19.1875   ,
#         19.5      , 19.8125   , 20.125    , 20.437498 , 20.75     ,
#         21.062498 , 21.374998 , 21.6875   ], dtype=float32),
#  'logits': array([[[ 2.0738040e+02, -1.4497301e+01,  1.9796606e+01, ...,
# ...

# %%
for thing in test['predicted_lddt']['logits']:
    print(len(thing))
# Out:
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# ...

# %%
test['representations'].keys()
# Out:
# dict_keys(['msa', 'msa_first_row', 'pair', 'single', 'structure_module'])

# %%
test['representations']['single'].shape
# Out:
# (411, 384)

# %%
test['representations']['pair'].shape
# Out:
# (411, 411, 128)

# %%
test['representations']['structure_module'].shape
# Out:
# (411, 384)

# %%
test['representations']['pair'][0][0].mean()
# Out:
# 2.5223336

# %%
for id, thing in enumerate(test['representations']['pair']):
    print(id, thing.mean())
# Out:
# 0 -0.24056356
# 1 -0.048409734
# 2 0.10155104
# 3 -0.29507527
# 4 0.35188168
# 5 0.22688477
# 6 0.15485336
# 7 0.38464174
# 8 0.40934622
# 9 0.35558867
# 10 0.3342811
# 11 0.34204182
# 12 0.6172582
# 13 0.37315726
# 14 0.30112442
# 15 0.4709407
# 16 0.48714218
# 17 0.6016505
# 18 0.28124678
# 19 0.5717964
# 20 0.4017278
# 21 0.34840357
# 22 0.32036653
# 23 0.53824234
# 24 0.18589671
# 25 0.2651318
# 26 0.536045
# 27 0.6401681
# 28 0.43027267
# 29 0.32077768
# 30 0.537188
# 31 0.18185832
# 32 0.34486225
# 33 0.7274919
# 34 0.5721041
# 35 0.32391006
# 36 0.43692994
# 37 0.43987596
# 38 0.42014152
# 39 0.36056548
# 40 0.2055625
# 41 0.47777987
# 42 0.3091239
# 43 0.48557293
# 44 0.37818244
# 45 0.2998719
# 46 0.556187
# 47 0.6032105
# 48 0.4461171
# 49 0.5426185
# 50 0.6736516
# 51 0.3174561
# 52 0.43096843
# 53 0.5917246
# 54 0.6543867
# 55 0.37113047
# 56 0.39983028
# 57 0.68010175
# 58 0.6204627
# 59 0.10164312
# 60 0.42430472
# 61 0.81325155
# 62 0.60183316
# 63 0.13909465
# ...

# %%
with open('params_model_5.npz', 'rb') as f:
    weights = np.load(f)

# %%
len(weights.files)
# Out:
# 265
